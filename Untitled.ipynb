# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %% [markdown]
# ### Importing data from local folder

# %%
GLEAM = pd.read_csv("Data/GLEAMorig.csv")

# %%
GLEAM.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 22 columns):
#  #   Column                                           Non-Null Count  Dtype
# ---  ------                                           --------------  -----
#  0   Region                                           583 non-null    object
#  1   Animal species                                   583 non-null    object
#  2   Production system                                583 non-null    object
#  3   Commodity                                        583 non-null    object
#  4   Emission Intensity (kg CO2e per kg protein)      583 non-null    float64
#  5   Production (kg protein)                          543 non-null    float64
#  6   Total GHG emissions (kg CO2e)                    543 non-null    float64
#  7   Total CO2 emissions (kg CO2e)                    543 non-null    float64
#  8   Total CH4 emissions (kg CO2e)                    543 non-null    float64
#  9   Total N2O emissions (kg CO2e)                    543 non-null    float64
#  10  Feed, CO2 (kg CO2e)                              543 non-null    float64
#  11  Feed, CH4 (kg CO2e)                              96 non-null     float64
#  12  Feed: fertilizer & crop residues, N2O (kg CO2e)  543 non-null    float64
#  13  Feed: applied & deposited manure, N2O (kg CO2e)  543 non-null    float64
#  14  LUC: soy & palm, CO2 (kg CO2e)                   440 non-null    float64
#  15  LUC: pasture expansion, CO2 (kg CO2e)            8 non-null      float64
#  16  Enteric fermentation, CH4 (kg CO2e)              425 non-null    float64
#  17  Manure management, CH4 (kg CO2e)                 543 non-null    float64
#  18  Manure management, N2O (kg CO2e)                 528 non-null    float64
#  19  Direct energy, CO2 (kg CO2e)                     503 non-null    float64
#  20  Indirect energy, CO2 (kg CO2e)                   512 non-null    float64
#  21  Postfarm, CO2 (kg CO2e)                          491 non-null    float64
# dtypes: float64(18), object(4)
# memory usage: 100.3+ KB

# %%
GLEAM1 = GLEAM.drop(['Commodity', 'Region', 'LUC: soy & palm, CO2 (kg CO2e)', 'LUC: pasture expansion, CO2 (kg CO2e)'], axis=1)

# %%
GLEAM1.head()
# Out:
#   Animal species  Production system  \
# 0         Cattle         Aggregated
# 1         Cattle         Aggregated
# 2         Cattle         Aggregated
# 3         Cattle  Grassland systems
# 4         Cattle  Grassland systems
#
#    Emission Intensity (kg CO2e per kg protein)  Production (kg protein)  \
# 0                                        160.3             2.916310e+10
# 1                                         86.7             1.888089e+10
# 2                                        295.4             1.028222e+10
# 3                                        206.3             1.033817e+10
# 4                                         95.0             6.940654e+09
#
#    Total GHG emissions (kg CO2e)  Total CO2 emissions (kg CO2e)  \
# 0                   4.670000e+12                   9.450000e+11
# 1                   1.640000e+12                   2.760000e+11
# 2                   3.040000e+12                   6.690000e+11
# 3                   2.130000e+12                   5.630000e+11
# 4                   6.590000e+11                   9.286140e+10
#
#    Total CH4 emissions (kg CO2e)  Total N2O emissions (kg CO2e)  \
# 0                   2.650000e+12                   1.080000e+12
# 1                   9.680000e+11                   3.940000e+11
# 2                   1.680000e+12                   6.870000e+11
# 3                   1.050000e+12                   5.170000e+11
# 4                   3.710000e+11                   1.950000e+11
#
#    Feed, CO2 (kg CO2e)  Feed, CH4 (kg CO2e)  \
# 0         3.530000e+11                  NaN
# 1         1.380000e+11                  NaN
# 2         2.150000e+11                  NaN
# 3         1.110000e+11                  NaN
# 4         4.404003e+10                  NaN
#
#    Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# 0                                     1.740000e+11
# 1                                     7.166208e+10
# 2                                     1.020000e+11
# 3                                     5.253660e+10
# 4                                     2.156126e+10
#
#    Feed: applied & deposited manure, N2O (kg CO2e)  \
# 0                                     7.420000e+11
# 1                                     2.540000e+11
# 2                                     4.880000e+11
# 3                                     4.270000e+11
# 4                                     1.590000e+11
#
#    LUC: pasture expansion, CO2 (kg CO2e)  Enteric fermentation, CH4 (kg CO2e)  \
# 0                           3.870000e+11                         2.510000e+12
# 1                                    NaN                         8.860000e+11
# 2                           3.870000e+11                         1.620000e+12
# 3                           3.870000e+11                         9.970000e+11
# 4                                    NaN                         3.370000e+11
#
#    Manure management, CH4 (kg CO2e)  Manure management, N2O (kg CO2e)  \
# 0                      1.390000e+11                      1.650000e+11
# 1                      8.200906e+10                      6.813278e+10
# 2                      5.744310e+10                      9.678019e+10
# 3                      5.605552e+10                      3.798508e+10
# 4                      3.444428e+10                      1.473188e+10
#
#    Direct energy, CO2 (kg CO2e)  Indirect energy, CO2 (kg CO2e)  \
# 0                  4.215542e+10                    1.585653e+10
# 1                  2.993485e+10                    3.252889e+09
# 2                  1.222057e+10                    1.260364e+10
# 3                  1.417326e+10                    4.303272e+09
# 4                  1.078605e+10                    9.998435e+08
#
#    Postfarm, CO2 (kg CO2e)
# 0             9.955932e+10
# 1             8.929544e+10
# 2             1.026388e+10
# 3             3.773092e+10
# 4             3.462338e+10

# %%
GLEAM1.corr(method='pearson')
# Out:
#                                                  Emission Intensity (kg CO2e per kg protein)  \
# Emission Intensity (kg CO2e per kg protein)                                         1.000000
# Production (kg protein)                                                            -0.084033
# Total GHG emissions (kg CO2e)                                                       0.173321
# Total CO2 emissions (kg CO2e)                                                       0.094549
# Total CH4 emissions (kg CO2e)                                                       0.200930
# Total N2O emissions (kg CO2e)                                                       0.162009
# Feed, CO2 (kg CO2e)                                                                 0.004201
# Feed, CH4 (kg CO2e)                                                                 0.289618
# Feed: fertilizer & crop residues, N2O (kg CO2e)                                     0.019845
# Feed: applied & deposited manure, N2O (kg CO2e)                                     0.206389
# Enteric fermentation, CH4 (kg CO2e)                                                 0.167511
# Manure management, CH4 (kg CO2e)                                                   -0.032064
# Manure management, N2O (kg CO2e)                                                    0.098768
# Direct energy, CO2 (kg CO2e)                                                       -0.162050
# Indirect energy, CO2 (kg CO2e)                                                      0.000746
# Postfarm, CO2 (kg CO2e)                                                            -0.123772
#
#                                                  Production (kg protein)  \
# Emission Intensity (kg CO2e per kg protein)                    -0.084033
# Production (kg protein)                                         1.000000
# Total GHG emissions (kg CO2e)                                   0.778108
# Total CO2 emissions (kg CO2e)                                   0.849576
# Total CH4 emissions (kg CO2e)                                   0.677091
# Total N2O emissions (kg CO2e)                                   0.797776
# Feed, CO2 (kg CO2e)                                             0.945389
# Feed, CH4 (kg CO2e)                                             0.491606
# Feed: fertilizer & crop residues, N2O (kg CO2e)                 0.933474
# Feed: applied & deposited manure, N2O (kg CO2e)                 0.680043
# Enteric fermentation, CH4 (kg CO2e)                             0.839568
# Manure management, CH4 (kg CO2e)                                0.724107
# Manure management, N2O (kg CO2e)                                0.823926
# Direct energy, CO2 (kg CO2e)                                    0.931646
# Indirect energy, CO2 (kg CO2e)                                  0.808579
# Postfarm, CO2 (kg CO2e)                                         0.916217
#
#                                                  Total GHG emissions (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                           0.173321
# Production (kg protein)                                               0.778108
# Total GHG emissions (kg CO2e)                                         1.000000
# Total CO2 emissions (kg CO2e)                                         0.889467
# Total CH4 emissions (kg CO2e)                                         0.977823
# Total N2O emissions (kg CO2e)                                         0.990693
# Feed, CO2 (kg CO2e)                                                   0.814539
# Feed, CH4 (kg CO2e)                                                   0.674620
# Feed: fertilizer & crop residues, N2O (kg CO2e)                       0.833524
# Feed: applied & deposited manure, N2O (kg CO2e)                       0.966014
# Enteric fermentation, CH4 (kg CO2e)                                   0.984958
# Manure management, CH4 (kg CO2e)                                      0.669039
# Manure management, N2O (kg CO2e)                                      0.929895
# Direct energy, CO2 (kg CO2e)                                          0.589799
# Indirect energy, CO2 (kg CO2e)                                        0.848962
# Postfarm, CO2 (kg CO2e)                                               0.720039
#
#                                                  Total CO2 emissions (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                           0.094549
# Production (kg protein)                                               0.849576
# Total GHG emissions (kg CO2e)                                         0.889467
# Total CO2 emissions (kg CO2e)                                         1.000000
# Total CH4 emissions (kg CO2e)                                         0.777306
# Total N2O emissions (kg CO2e)                                         0.870825
# Feed, CO2 (kg CO2e)                                                   0.876347
# Feed, CH4 (kg CO2e)                                                   0.499462
# Feed: fertilizer & crop residues, N2O (kg CO2e)                       0.856453
# Feed: applied & deposited manure, N2O (kg CO2e)                       0.819352
# Enteric fermentation, CH4 (kg CO2e)                                   0.873359
# Manure management, CH4 (kg CO2e)                                      0.637681
# Manure management, N2O (kg CO2e)                                      0.782907
# Direct energy, CO2 (kg CO2e)                                          0.751739
# Indirect energy, CO2 (kg CO2e)                                        0.809136
# Postfarm, CO2 (kg CO2e)                                               0.713655
#
#                                                  Total CH4 emissions (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                           0.200930
# Production (kg protein)                                               0.677091
# Total GHG emissions (kg CO2e)                                         0.977823
# Total CO2 emissions (kg CO2e)                                         0.777306
# Total CH4 emissions (kg CO2e)                                         1.000000
# Total N2O emissions (kg CO2e)                                         0.966025
# Feed, CO2 (kg CO2e)                                                   0.717873
# Feed, CH4 (kg CO2e)                                                   0.933930
# Feed: fertilizer & crop residues, N2O (kg CO2e)                       0.753247
# Feed: applied & deposited manure, N2O (kg CO2e)                       0.955775
# Enteric fermentation, CH4 (kg CO2e)                                   0.997186
# Manure management, CH4 (kg CO2e)                                      0.629329
# Manure management, N2O (kg CO2e)                                      0.925213
# Direct energy, CO2 (kg CO2e)                                          0.459156
# Indirect energy, CO2 (kg CO2e)                                        0.798497
# Postfarm, CO2 (kg CO2e)                                               0.660929
#
#                                                  Total N2O emissions (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                           0.162009
# Production (kg protein)                                               0.797776
# Total GHG emissions (kg CO2e)                                         0.990693
# Total CO2 emissions (kg CO2e)                                         0.870825
# Total CH4 emissions (kg CO2e)                                         0.966025
# Total N2O emissions (kg CO2e)                                         1.000000
# Feed, CO2 (kg CO2e)                                                   0.827544
# Feed, CH4 (kg CO2e)                                                   0.638671
# Feed: fertilizer & crop residues, N2O (kg CO2e)                       0.846940
# Feed: applied & deposited manure, N2O (kg CO2e)                       0.975001
# Enteric fermentation, CH4 (kg CO2e)                                   0.977797
# Manure management, CH4 (kg CO2e)                                      0.675677
# Manure management, N2O (kg CO2e)                                      0.931970
# Direct energy, CO2 (kg CO2e)                                          0.614635
# Indirect energy, CO2 (kg CO2e)                                        0.856740
# Postfarm, CO2 (kg CO2e)                                               0.735401
#
#                                                  Feed, CO2 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                 0.004201
# Production (kg protein)                                     0.945389
# Total GHG emissions (kg CO2e)                               0.814539
# Total CO2 emissions (kg CO2e)                               0.876347
# Total CH4 emissions (kg CO2e)                               0.717873
# Total N2O emissions (kg CO2e)                               0.827544
# Feed, CO2 (kg CO2e)                                         1.000000
# Feed, CH4 (kg CO2e)                                         0.625032
# Feed: fertilizer & crop residues, N2O (kg CO2e)             0.990703
# Feed: applied & deposited manure, N2O (kg CO2e)             0.695689
# Enteric fermentation, CH4 (kg CO2e)                         0.853993
# Manure management, CH4 (kg CO2e)                            0.732654
# Manure management, N2O (kg CO2e)                            0.866729
# Direct energy, CO2 (kg CO2e)                                0.851892
# Indirect energy, CO2 (kg CO2e)                              0.809461
# Postfarm, CO2 (kg CO2e)                                     0.824800
#
#                                                  Feed, CH4 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                 0.289618
# Production (kg protein)                                     0.491606
# Total GHG emissions (kg CO2e)                               0.674620
# Total CO2 emissions (kg CO2e)                               0.499462
# Total CH4 emissions (kg CO2e)                               0.933930
# Total N2O emissions (kg CO2e)                               0.638671
# Feed, CO2 (kg CO2e)                                         0.625032
# Feed, CH4 (kg CO2e)                                         1.000000
# Feed: fertilizer & crop residues, N2O (kg CO2e)             0.656701
# Feed: applied & deposited manure, N2O (kg CO2e)             0.403717
# Enteric fermentation, CH4 (kg CO2e)                         0.900030
# Manure management, CH4 (kg CO2e)                            0.907921
# Manure management, N2O (kg CO2e)                            0.771021
# Direct energy, CO2 (kg CO2e)                                0.210091
# Indirect energy, CO2 (kg CO2e)                              0.306427
# Postfarm, CO2 (kg CO2e)                                     0.467863
#
#                                                  Feed: fertilizer & crop residues, N2O (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                                             0.019845
# Production (kg protein)                                                                 0.933474
# Total GHG emissions (kg CO2e)                                                           0.833524
# Total CO2 emissions (kg CO2e)                                                           0.856453
# Total CH4 emissions (kg CO2e)                                                           0.753247
# Total N2O emissions (kg CO2e)                                                           0.846940
# Feed, CO2 (kg CO2e)                                                                     0.990703
# Feed, CH4 (kg CO2e)                                                                     0.656701
# Feed: fertilizer & crop residues, N2O (kg CO2e)                                         1.000000
# Feed: applied & deposited manure, N2O (kg CO2e)                                         0.713768
# Enteric fermentation, CH4 (kg CO2e)                                                     0.860619
# Manure management, CH4 (kg CO2e)                                                        0.741359
# Manure management, N2O (kg CO2e)                                                        0.897700
# Direct energy, CO2 (kg CO2e)                                                            0.818564
# Indirect energy, CO2 (kg CO2e)                                                          0.800817
# Postfarm, CO2 (kg CO2e)                                                                 0.847474
#
#                                                  Feed: applied & deposited manure, N2O (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                                             0.206389
# Production (kg protein)                                                                 0.680043
# Total GHG emissions (kg CO2e)                                                           0.966014
# Total CO2 emissions (kg CO2e)                                                           0.819352
# Total CH4 emissions (kg CO2e)                                                           0.955775
# Total N2O emissions (kg CO2e)                                                           0.975001
# Feed, CO2 (kg CO2e)                                                                     0.695689
# Feed, CH4 (kg CO2e)                                                                     0.403717
# Feed: fertilizer & crop residues, N2O (kg CO2e)                                         0.713768
# Feed: applied & deposited manure, N2O (kg CO2e)                                         1.000000
# Enteric fermentation, CH4 (kg CO2e)                                                     0.959170
# Manure management, CH4 (kg CO2e)                                                        0.579266
# Manure management, N2O (kg CO2e)                                                        0.844403
# Direct energy, CO2 (kg CO2e)                                                            0.495467
# Indirect energy, CO2 (kg CO2e)                                                          0.804424
# Postfarm, CO2 (kg CO2e)                                                                 0.625501
#
#                                                  Enteric fermentation, CH4 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                                 0.167511
# Production (kg protein)                                                     0.839568
# Total GHG emissions (kg CO2e)                                               0.984958
# Total CO2 emissions (kg CO2e)                                               0.873359
# Total CH4 emissions (kg CO2e)                                               0.997186
# Total N2O emissions (kg CO2e)                                               0.977797
# Feed, CO2 (kg CO2e)                                                         0.853993
# Feed, CH4 (kg CO2e)                                                         0.900030
# Feed: fertilizer & crop residues, N2O (kg CO2e)                             0.860619
# Feed: applied & deposited manure, N2O (kg CO2e)                             0.959170
# Enteric fermentation, CH4 (kg CO2e)                                         1.000000
# Manure management, CH4 (kg CO2e)                                            0.567119
# Manure management, N2O (kg CO2e)                                            0.927451
# Direct energy, CO2 (kg CO2e)                                                0.801548
# Indirect energy, CO2 (kg CO2e)                                              0.870695
# Postfarm, CO2 (kg CO2e)                                                     0.723254
#
#                                                  Manure management, CH4 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                             -0.032064
# Production (kg protein)                                                  0.724107
# Total GHG emissions (kg CO2e)                                            0.669039
# Total CO2 emissions (kg CO2e)                                            0.637681
# Total CH4 emissions (kg CO2e)                                            0.629329
# Total N2O emissions (kg CO2e)                                            0.675677
# Feed, CO2 (kg CO2e)                                                      0.732654
# Feed, CH4 (kg CO2e)                                                      0.907921
# Feed: fertilizer & crop residues, N2O (kg CO2e)                          0.741359
# Feed: applied & deposited manure, N2O (kg CO2e)                          0.579266
# Enteric fermentation, CH4 (kg CO2e)                                      0.567119
# Manure management, CH4 (kg CO2e)                                         1.000000
# Manure management, N2O (kg CO2e)                                         0.748589
# Direct energy, CO2 (kg CO2e)                                             0.532616
# Indirect energy, CO2 (kg CO2e)                                           0.631428
# Postfarm, CO2 (kg CO2e)                                                  0.692878
#
#                                                  Manure management, N2O (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                              0.098768
# Production (kg protein)                                                  0.823926
# Total GHG emissions (kg CO2e)                                            0.929895
# Total CO2 emissions (kg CO2e)                                            0.782907
# Total CH4 emissions (kg CO2e)                                            0.925213
# Total N2O emissions (kg CO2e)                                            0.931970
# Feed, CO2 (kg CO2e)                                                      0.866729
# Feed, CH4 (kg CO2e)                                                      0.771021
# Feed: fertilizer & crop residues, N2O (kg CO2e)                          0.897700
# Feed: applied & deposited manure, N2O (kg CO2e)                          0.844403
# Enteric fermentation, CH4 (kg CO2e)                                      0.927451
# Manure management, CH4 (kg CO2e)                                         0.748589
# Manure management, N2O (kg CO2e)                                         1.000000
# Direct energy, CO2 (kg CO2e)                                             0.631270
# Indirect energy, CO2 (kg CO2e)                                           0.830868
# Postfarm, CO2 (kg CO2e)                                                  0.787634
#
#                                                  Direct energy, CO2 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                         -0.162050
# Production (kg protein)                                              0.931646
# Total GHG emissions (kg CO2e)                                        0.589799
# Total CO2 emissions (kg CO2e)                                        0.751739
# Total CH4 emissions (kg CO2e)                                        0.459156
# Total N2O emissions (kg CO2e)                                        0.614635
# Feed, CO2 (kg CO2e)                                                  0.851892
# Feed, CH4 (kg CO2e)                                                  0.210091
# Feed: fertilizer & crop residues, N2O (kg CO2e)                      0.818564
# Feed: applied & deposited manure, N2O (kg CO2e)                      0.495467
# Enteric fermentation, CH4 (kg CO2e)                                  0.801548
# Manure management, CH4 (kg CO2e)                                     0.532616
# Manure management, N2O (kg CO2e)                                     0.631270
# Direct energy, CO2 (kg CO2e)                                         1.000000
# Indirect energy, CO2 (kg CO2e)                                       0.738609
# Postfarm, CO2 (kg CO2e)                                              0.835644
#
#                                                  Indirect energy, CO2 (kg CO2e)  \
# Emission Intensity (kg CO2e per kg protein)                            0.000746
# Production (kg protein)                                                0.808579
# Total GHG emissions (kg CO2e)                                          0.848962
# Total CO2 emissions (kg CO2e)                                          0.809136
# Total CH4 emissions (kg CO2e)                                          0.798497
# Total N2O emissions (kg CO2e)                                          0.856740
# Feed, CO2 (kg CO2e)                                                    0.809461
# Feed, CH4 (kg CO2e)                                                    0.306427
# Feed: fertilizer & crop residues, N2O (kg CO2e)                        0.800817
# Feed: applied & deposited manure, N2O (kg CO2e)                        0.804424
# Enteric fermentation, CH4 (kg CO2e)                                    0.870695
# Manure management, CH4 (kg CO2e)                                       0.631428
# Manure management, N2O (kg CO2e)                                       0.830868
# Direct energy, CO2 (kg CO2e)                                           0.738609
# Indirect energy, CO2 (kg CO2e)                                         1.000000
# Postfarm, CO2 (kg CO2e)                                                0.673094
#
#                                                  Postfarm, CO2 (kg CO2e)
# Emission Intensity (kg CO2e per kg protein)                    -0.123772
# Production (kg protein)                                         0.916217
# Total GHG emissions (kg CO2e)                                   0.720039
# Total CO2 emissions (kg CO2e)                                   0.713655
# Total CH4 emissions (kg CO2e)                                   0.660929
# Total N2O emissions (kg CO2e)                                   0.735401
# Feed, CO2 (kg CO2e)                                             0.824800
# Feed, CH4 (kg CO2e)                                             0.467863
# Feed: fertilizer & crop residues, N2O (kg CO2e)                 0.847474
# Feed: applied & deposited manure, N2O (kg CO2e)                 0.625501
# Enteric fermentation, CH4 (kg CO2e)                             0.723254
# Manure management, CH4 (kg CO2e)                                0.692878
# Manure management, N2O (kg CO2e)                                0.787634
# Direct energy, CO2 (kg CO2e)                                    0.835644
# Indirect energy, CO2 (kg CO2e)                                  0.673094
# Postfarm, CO2 (kg CO2e)                                         1.000000

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn import metrics
import numpy as np

# %%
#Titanic.pclass.value_counts()

# %%
#def embarked (series):
#    if series == "S":
#        return 0
 ##   if series == "C":
 #       return 1
  #  if series == "Q":
 #       return 3
#Titanic6['EmbarkedR'] = Titanic6['embarked'].apply(embarked)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_24904/2217488607.py in <module>
# ----> 1 GLEAM1.animalspecies.value_counts()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'animalspecies'

# %%
def Production_system (series):
    if series ==""
